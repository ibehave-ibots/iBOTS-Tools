# %% [markdown]
# # Session 3 - Fun with Functions

# %% [markdown]
# Tired of repeating the same old code again and again? That's where functions come in!
#
# In this session we will be designing functions to programm an automatic lighthouse with lEDs, a light sensor and a speaker.

# %% [markdown]
# ## Learning Goals
#
# - A
# - B

# %% [markdown]
# ## Circuit
#
# In this session we will be using 3 LEDs, 3 push buttons, a light sensor module and a speaker connected to the Arduino like so
#
# | Component    | Pin |
# | -------- | ------- |
# | Red LED  |  3   |
# | Green LED |  4    |
# | Purple LED    |  5   |
# | Purple Push Button    |  9    |
# | Green Push Button     |  10    |
# | Red Push Button    |    11  |
# | Light Sensor Module    |    12  |
# | Speaker    |    8  |

# %% [markdown]
# ## Exercises
#
#
# #### Example Exercise
#
# The code below is in `src/main.cpp`. When the green button is pressed the green LED turns on. Write a function called `GreenButtonPressed` that turns on the LED. Call this function when the green button is pressed.
#
# ```
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
# }
#
# void loop() {
#   if (digitalRead(GreenButton)==LOW){
#     digitalWrite(GreenLED, HIGH);
#   }
# }
#
# ```

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
# }
#
# void loop() {
#   if (digitalRead(GreenButton)==LOW){
#     GreenButtonPressed();
#   }
#
# }

# %% [markdown]
# **Ex. 1** Write another function called `RedButtonPressed` that lights up the red LED. Call this function when the red button is pressed

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void loop() {
#   if (digitalRead(GreenButton)==LOW){
#     GreenButtonPressed();
#   }
#    if (digitalRead(RedButton)==LOW){
#     RedButtonPressed();
#   }
#
# }

# %% [markdown]
# **Ex. 2** Write a function called `YellowButtonPressed` that turns off the red and green LEDS. Call this function when the yellow button is pressed.

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         RedButtonPressed();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         YellowButtonPressed();
#   }
# }

# %% [markdown]
# **Ex. 3** Edit the function `GreenButtonPressed` so that the green LED turns on for 1 second and then turns off.

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
#     delay(1000);
#     digitalWrite(GreenLED, LOW);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         RedButtonPressed();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         YellowButtonPressed();
#   }
# }

# %% [markdown]
# **Ex. 4** Write a function called `FlashAllLEDs` that turns on every LED for 0.5 seconds. Use this function to turn on the LEDs at the start of your program (ie. in the setup block)

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void FlashAllLEDs(){
#     digitalWrite(RedLED, HIGH);
#     digitalWrite(GreenLED, HIGH);
#     digitalWrite(PurpleLED, HIGH);
#
#     delay(500);
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
#     digitalWrite(PurpleLED, LOW);
#
# }
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
#   FlashAllLEDs();
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
#     delay(1000);
#     digitalWrite(GreenLED, LOW);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         RedButtonPressed();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         YellowButtonPressed();
#   }
# }

# %% [markdown]
# **Ex. 5** A lighthouse needs to be able to communicate in Morse code. Fill in the blanks below to write a function that flashes the SOS signal on the purple LED. Use this function so that the SOS signal is shown when the yellow button is pressed.
#
# ```
# void SOS(){
#
#   const int LEDToFlash = ___________;
#
#   // 3 short flashes
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(1000);
#
#   // 3 long flashes
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#
#   // 3 short flashes
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
# }
# ```

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void FlashAllLEDs(){
#     digitalWrite(RedLED, HIGH);
#     digitalWrite(GreenLED, HIGH);
#     digitalWrite(PurpleLED, HIGH);
#
#     delay(500);
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
#     digitalWrite(PurpleLED, LOW);
#
# }
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
#   FlashAllLEDs();
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
#     delay(1000);
#     digitalWrite(GreenLED, LOW);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
#
# void SOS(){
#
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(1000);
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
# }
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         RedButtonPressed();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         SOS();
#   }
# }

# %% [markdown]
# **Ex. 6** The function `SOS` is very long and hard to follow. Let's break it up into smaller chunks. Write a function called `shortFlash` that makes the purpleLED flash once for 200ms. Test your function by calling it when the red button is pressed

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void FlashAllLEDs(){
#     digitalWrite(RedLED, HIGH);
#     digitalWrite(GreenLED, HIGH);
#     digitalWrite(PurpleLED, HIGH);
#
#     delay(500);
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
#     digitalWrite(PurpleLED, LOW);
#
# }
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
#   FlashAllLEDs();
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
#     delay(1000);
#     digitalWrite(GreenLED, LOW);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
#
# void SOS(){
#
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(1000);
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
# }
#
# void shortFlash(){
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
# }
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         shortFlash();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         SOS();
#   }
# }

# %% [markdown]
# **Ex. 7** Write another function called `longFlash` that flashes the purple LED for 500ms.

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void FlashAllLEDs(){
#     digitalWrite(RedLED, HIGH);
#     digitalWrite(GreenLED, HIGH);
#     digitalWrite(PurpleLED, HIGH);
#
#     delay(500);
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
#     digitalWrite(PurpleLED, LOW);
#
# }
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
#   FlashAllLEDs();
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
#     delay(1000);
#     digitalWrite(GreenLED, LOW);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
#
# void SOS(){
#
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(1000);
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
# }
#
# void shortFlash(){
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
# }
#
# void longFlash(){
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
# }
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         RedButtonPressed();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         longFlash();
#   }
# }

# %% [markdown]
# **Ex. 8** Rewrite the function `SOS` to use the functions `shortFlash` and `longFlash`. **Hint-** you might need to change the order in which the functions are defined in the code

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
# void FlashAllLEDs(){
#     digitalWrite(RedLED, HIGH);
#     digitalWrite(GreenLED, HIGH);
#     digitalWrite(PurpleLED, HIGH);
#
#     delay(500);
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
#     digitalWrite(PurpleLED, LOW);
#
# }
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
#   FlashAllLEDs();
#
# }
#
# void GreenButtonPressed(){
#     digitalWrite(GreenLED, HIGH);
#     delay(1000);
#     digitalWrite(GreenLED, LOW);
# }
#
# void RedButtonPressed(){
#     digitalWrite(RedLED, HIGH);
# }
#
# void YellowButtonPressed(){
#     digitalWrite(RedLED, LOW);
#     digitalWrite(GreenLED, LOW);
# }
#
# void shortFlash(){
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
# }
#
# void longFlash(){
#   const int LEDToFlash =PurpleLED;
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
# }
#
# void SOS(){
#
#   const int LEDToFlash =PurpleLED;
#
#   // 3 short flashes
#   shortFlash();
#   shortFlash();
#   shortFlash();
#   delay(1000);
#
#   // 3 long flashes
#   longFlash();
#   longFlash();
#   longFlash();
#   delay(1000);
#
#   // 3 short flashes
#   shortFlash();
#   shortFlash();
#   shortFlash();
# }
#
#
#
# void loop() {
#     if (digitalRead(GreenButton)==LOW){
#         GreenButtonPressed();
#   }
#     if (digitalRead(RedButton)==LOW){
#         RedButtonPressed();
#   }
#      if (digitalRead(YellowButton)==LOW){
#         SOS();
#   }
# }

# %% [markdown]
# **Ex. 9** Our SOS function is now so much more readable! But what if we want to flash the SOS signal on a different LED? In the code below, Add an argument to the function `shortFlash` that allows us to set the LED that will be used. Use the `shortFlash` function to flash the green LED when the green button is pressed.
#
# ```
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
#
# void shortFlash(){
#   const int LEDToFlash = PurpleLED;
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
# }
#
# void longFlash(){
#   const int LEDToFlash = PurpleLED;
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
# }
#
#
#
# void loop() {
#
#   if (digitalRead(GreenButton)==LOW){
#         shortFlash(GreenLED);
#   }
#
# }
# ```

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
#
# void shortFlash(int LEDToFlash){
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
# }
#
# void longFlash(){
#   const int LEDToFlash = PurpleLED;
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
# }
#
#
# void loop() {
#
#   if (digitalRead(GreenButton)==LOW){
#         shortFlash(GreenLED);
#   }
#
# }

# %% [markdown]
# **Ex. 10** Do the same for the function `longFlash` and use the green button to make a long flash on the green LED

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
#
# void shortFlash(int LEDToFlash){
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
# }
#
# void longFlash(int LEDToFlash){
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
# }
#
#
#
#
# void loop() {
#
#   if (digitalRead(RedButton)==LOW){
#        shortFlash(RedLED);
#   }
#
#   if (digitalRead(GreenButton)==LOW){
#        longFlash(GreenLED);
#   }
#
#
# }

# %% [markdown]
# **Ex. 11**  Rewrite the `SOS` function below to take an argument that sets which LED to flash. Then write a program that displays the SOS signal on the red LED and then on the green LED when the red button is pressed.
#
# ```
# void SOS(){
#
#   const int LEDToFlash =PurpleLED;
#   // 3 short flashes
#   shortFlash();
#   shortFlash();
#   shortFlash();
#   delay(1000);
#
#   // 3 long flashes
#   longFlash();
#   longFlash();
#   longFlash();
#   delay(1000);
#
#   // 3 short flashes
#   shortFlash();
#   shortFlash();
#   shortFlash();
# }
# ```

# %% [raw]
# #include <Arduino.h>
#
# // variables for components on each pin
# const int GreenButton = 11;
# const int YellowButton = 10;
# const int RedButton = 9;
#
# const int RedLED = 3;
# const int GreenLED = 4;
# const int PurpleLED = 5;
#
# const int Speaker = 8;
# const int LightSensor = 12;
#
#
# void setup() {
#   pinMode(RedLED, OUTPUT);
#   pinMode(GreenLED, OUTPUT);
#   pinMode(PurpleLED, OUTPUT);
#   pinMode(Speaker, OUTPUT);
#
#   pinMode(GreenButton, INPUT_PULLUP);
#   pinMode(YellowButton, INPUT_PULLUP);
#   pinMode(RedButton, INPUT_PULLUP);
#
#   pinMode(LightSensor, INPUT);
#
# }
#
#
# void shortFlash(int LEDToFlash){
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(200);
#   digitalWrite(LEDToFlash, LOW);
#   delay(200);
# }
#
# void longFlash(int LEDToFlash){
#
#   digitalWrite(LEDToFlash, HIGH);
#   delay(500);
#   digitalWrite(LEDToFlash, LOW);
#   delay(500);
# }
#
# void SOS(int LEDToFlash){
#
#   // 3 short flashes
#   shortFlash(LEDToFlash);
#   shortFlash(LEDToFlash);
#   shortFlash(LEDToFlash);
#   delay(1000);
#
#   // 3 long flashes
#   longFlash(LEDToFlash);
#   longFlash(LEDToFlash);
#   longFlash(LEDToFlash);
#   delay(1000);
#
#   // 3 short flashes
#   shortFlash(LEDToFlash);
#   shortFlash(LEDToFlash);
#   shortFlash(LEDToFlash);
# }
#
#
# void loop() {
#
#   if (digitalRead(RedButton)==LOW){
#        SOS(RedLED);
#        delay(100);
#        SOS(GreenLED);
#   }
#
#   if (digitalRead(GreenButton)==LOW){
#        longFlash(GreenLED);
#   }
#
#
#
# }

# %% [markdown]
# **Ex. 12**

# %% [markdown]
# **Ex. 13**

# %% [markdown]
# **Ex. 14**

# %% [markdown]
# - make sos function on any LED
#
# - include light sensor
#
# - include speaker
