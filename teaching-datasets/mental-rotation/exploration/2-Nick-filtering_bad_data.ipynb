# %%
# %pip install pandas plotly nbformat>=4.2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Mental Rotation Exploration: Second Round
#
# Try out this time:
#   - Are there any obvious bad data?
#   - How are histograms with Plotly Express?
#   - Can I make interactive charts with Ploty Express? 🙃

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('../data/MentalRotation.csv')
df.head()
# Out:
#    Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 0       49      1      0         0        n  3107        1   32   M
# 1       49      2    150         0        n  2930        1   32   M
# 2       49      3    150         1        b  1874        1   32   M
# 3       49      4    100         1        b  3793        1   32   M
# 4       49      5     50         1        b  2184        1   32   M

# %% [markdown]
# ## Get Distribution of Response Times

# %%
px.box(x=df.Angle, y=df.Time)

# %%
px.violin(x=df.Angle, y=df.Time)

# %%
px.violin(x=df.Angle, y=df.Time, color=df.Angle)

# %%
px.histogram(x=df.Time, color=df.Matching)

# %%
px.histogram(
    x=df.Time, 
    facet_col=df.Matching, 
    facet_row=df.Sex, 
    color=df.Correct, 
    histnorm="percent", 
    nbins=25,
    title='Distribution of Response Times',
    width=600,
    height=400,
)

# %%
px.histogram(
    data_frame=df,
    x='Time', 
    facet_col='Matching', 
    facet_row='Sex', 
    color='Correct', 
    histnorm="percent", 
    nbins=25,
    title='Distribution of Response Times',
    width=600,
    height=400,
    animation_frame='Age',

)
